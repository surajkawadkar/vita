# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np

# %%
# for local machine neede library from NLP
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\abc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\abc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
content = '''NEW DELHI: India's manufacturing output showed the strongest growth in 13 years in October amid robust sales growth, IHS Markit India purchasing managers’ index showed, indicating economic recovery was gaining ground after the lifting of lockdown restrictions.

Rising to 58.9 in October from 56.8 in September, the headline seasonally adjusted PMI pointed to the strongest improvement in the health of the sector in over a decade, the information provider said in a statement on Monday. A reading above 50 shows expansion from the previous month.

The index is compiled from responses in the second half of the month from around 400 manufacturers, which indicates the direction of change compared to the previous month.

The IHS Markit India statement said growth was led by the intermediate goods category, but there were also robust expansions in the consumer and investment goods sub-sectors.

Manufacturers indicated that the ongoing relaxation of Covid-19 restrictions, better market conditions and improved demand helped them secure new work in October. Also, the upturn in sales was the strongest since mid-2008. New export orders too rose at a quicker pace, one that was the most pronounced in close to six years, said the company.

Greater production needs led to another monthly increase in input buying among Indian manufacturers. Moreover, quantities of purchases rose at the quickest pace in just under nine years. Inflationary pressures, meanwhile, remained subdued as seen by a modest increase in input costs and only marginal rise in selling prices, the statement said.

The data conforms to a strong jump in e-way bills for October indicating that more goods were shipped within and across states in the month. Generation of e-way bills (electronic permits for goods movement) in October was 21% higher than what was generated in October 2019 and 11% higher than what was generated in September this year. This early indicator suggests increased economic activity in October, Mint reported on Monday.

India’s industrial output for the month of August too had shown a trend of economic recovery. Factory output had contracted at a slower 8% in August compared to a 10.8% contraction July.

“Levels of new orders and output at Indian manufacturers continued to recover from the Covid-19 induced contractions seen earlier in the year, with the PMI results for October highlighting historically-sharp monthly rates of expansion," the statement said quoting Pollyanna De Lima, economics associate director at IHS Markit. Companies were convinced that the resurgence in sales will be sustained in coming months, as indicated by a strong upturn in input buying amid restocking efforts, said Lima.'''

# %%
wc = WordCloud()
plt.imshow(wc.generate(content))
plt.axis('Off')
plt.show()

# %%
from wordcloud import STOPWORDS

# %%
len(STOPWORDS)
# Out:
# 192

# %%
type(STOPWORDS)
# Out:
# set

# %%
STOPWORDS = STOPWORDS.add('said')

# %%
wc = WordCloud(stopwords = STOPWORDS,
              colormap='Reds',
              max_words=30)
mycloud = wc.generate(content)
plt.imshow(mycloud)
plt.axis('Off')
plt.show()

# %%
mycloud.words_
# Out:
# {'October': 1.0,
#  'month': 0.75,
#  'year': 0.625,
#  'new': 0.5,
#  'India': 0.5,
#  'output': 0.5,
#  'economic': 0.5,
#  'statement': 0.5,
#  'manufacturers': 0.5,
#  'goods': 0.5,
#  'strongest': 0.375,
#  'growth': 0.375,
#  'sales': 0.375,
#  'expansion': 0.375,
#  'input': 0.375,
#  'IHS Markit': 0.375,
#  'showed': 0.25,
#  'amid': 0.25,
#  'robust': 0.25,
#  'index': 0.25,
#  'indicating': 0.25,
#  'recovery': 0.25,
#  'restrictions': 0.25,
#  'September': 0.25,
#  'PMI': 0.25,
#  'sector': 0.25,
#  'Monday': 0.25,
#  'previous': 0.25,
#  'compared': 0.25,
#  'led': 0.25}

# %%
#!pip install textblob

# %%
from textblob import TextBlob

# %%
text = "This is a difficult course."

# %%
text=TextBlob(text)

# %%
text.tags
# Out:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/english.pickle
#
#   Searched in:
#     - 'C:\\Users\\abc/nltk_data'
#     - 'c:\\users\\abc\\appdata\\local\\programs\\python\\python37-32\\nltk_data'
#     - 'c:\\users\\abc\\appdata\\local\\programs\\python\\python37-32\\share\\nltk_data'
#     - 'c:\\users\\abc\\appdata\\local\\programs\\python\\python37-32\\lib\\nltk_data'
#     - 'C:\\Users\\abc\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\textblob\decorators.py in decorated(*args, **kwargs)
#      34         try:
# ---> 35             return func(*args, **kwargs)
#      36         except LookupError as err:
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\textblob\tokenizers.py in tokenize(self, text)
#      56         '''Return a list of sentences.'''
# ---> 57         return nltk.tokenize.sent_tokenize(text)
#      58
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     106     """
# --> 107     tokenizer = load("tokenizers/punkt/{0}.pickle".format(language))
#     108     return tokenizer.tokenize(text)
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\nltk\data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     749     # Load the resource.
# --> 750     opened_resource = _open(resource_url)
#     751
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\nltk\data.py in _open(resource_url)
#     874     if protocol is None or protocol.lower() == "nltk":
# --> 875         return find(path_, path + [""]).open()
#     876     elif protocol.lower() == "file":
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = "\n%s\n%s\n%s\n" % (sep, msg, sep)
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/english.pickle
#
#   Searched in:
#     - 'C:\\Users\\abc/nltk_data'
#     - 'c:\\users\\abc\\appdata\\local\\programs\\python\\python37-32\\nltk_data'
#     - 'c:\\users\\abc\\appdata\\local\\programs\\python\\python37-32\\share\\nltk_data'
#     - 'c:\\users\\abc\\appdata\\local\\programs\\python\\python37-32\\lib\\nltk_data'
#     - 'C:\\Users\\abc\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# MissingCorpusError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_988/1757559026.py in <module>
# ----> 1 text.tags
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\textblob\decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\textblob\blob.py in pos_tags(self)
#     482         """
#     483         if isinstance(self, TextBlob):
# --> 484             return [val for sublist in [s.pos_tags for s in self.sentences] for val in sublist]
#     485         else:
#     486             return [(Word(unicode(word), pos_tag=t), unicode(t))
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\textblob\decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\textblob\blob.py in sentences(self)
#     637     def sentences(self):
#     638         """Return list of :class:`Sentence <Sentence>` objects."""
# --> 639         return self._create_sentence_objects()
#     640
#     641     @cached_property
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\textblob\blob.py in _create_sentence_objects(self)
#     681         '''
#     682         sentence_objects = []
# --> 683         sentences = sent_tokenize(self.raw)
#     684         char_index = 0  # Keeps track of character index within the blob
#     685         for sent in sentences:
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\textblob\base.py in itokenize(self, text, *args, **kwargs)
#      62         :rtype: generator
#      63         """
# ---> 64         return (t for t in self.tokenize(text, *args, **kwargs))
#      65
#      66 ##### SENTIMENT ANALYZERS ####
#
# c:\users\abc\appdata\local\programs\python\python37-32\lib\site-packages\textblob\decorators.py in decorated(*args, **kwargs)
#      36         except LookupError as err:
#      37             print(err)
# ---> 38             raise MissingCorpusError()
#      39     return decorated
#
# MissingCorpusError:
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.

# %%
from textblob import Word

# %%
w=Word('fase')
w.spellcheck()
# Out:
# [('face', 0.5927291886195996),
#  ('case', 0.23076923076923078),
#  ('fate', 0.051633298208640675),
#  ('false', 0.03371970495258166),
#  ('base', 0.02792413066385669),
#  ('ease', 0.023182297154899896),
#  ('fast', 0.02054794520547945),
#  ('fame', 0.007903055848261328),
#  ('fare', 0.0036880927291886197),
#  ('fuse', 0.003161222339304531),
#  ('fade', 0.003161222339304531),
#  ('vase', 0.0005268703898840885),
#  ('gase', 0.0005268703898840885),
#  ('fas', 0.0005268703898840885)]

# %%
animal=TextBlob('cat,dog')
animal.words.pluralize()
# Out:
# WordList(['cats', 'dogs'])

# %%
from textblob.wordnet import Synset

# %%
word1=Word('Bull')
word1.synsets
# Out:
# [Synset('bull.n.01'),
#  Synset('bull.n.02'),
#  Synset('bullshit.n.01'),
#  Synset('bull.n.04'),
#  Synset('bull.n.05'),
#  Synset('bull.n.06'),
#  Synset('taurus.n.02'),
#  Synset('taurus.n.04'),
#  Synset('bull's_eye.n.02'),
#  Synset('bull.n.10'),
#  Synset('bull.n.11'),
#  Synset('bull.v.01'),
#  Synset('bull.v.02'),
#  Synset('talk_through_one's_hat.v.01'),
#  Synset('bull.v.04')]

# %%
word1.definitions
# Out:
# ['uncastrated adult male of domestic cattle',
#  'a large and strong and heavyset man',
#  'obscene words for unacceptable behavior',
#  'a serious and ludicrous blunder',
#  'uncomplimentary terms for a policeman',
#  'an investor with an optimistic market outlook; an investor who expects prices to rise and so buys now for resale later',
#  '(astrology) a person who is born while the sun is in Taurus',
#  'the second sign of the zodiac; the sun is in this sign from about April 20 to May 20',
#  'the center of a target',
#  'a formal proclamation issued by the pope (usually written in antiquated characters and sealed with a leaden bulla)',
#  "mature male of various mammals of which the female is called `cow'; e.g. whales or elephants or especially cattle",
#  'push or force',
#  'try to raise the price of stocks through speculative buying',
#  'speak insincerely or without regard for facts or truths',
#  'advance in price']

# %%
word2=Word('market')
word2.synsets
# Out:
# [Synset('market.n.01'),
#  Synset('market.n.02'),
#  Synset('grocery_store.n.01'),
#  Synset('market.n.04'),
#  Synset('marketplace.n.02'),
#  Synset('market.v.01'),
#  Synset('market.v.02'),
#  Synset('market.v.03'),
#  Synset('commercialize.v.02')]

# %%
# n-grams means one word at a time
text = TextBlob('now is better than tomorrow.')

# %%
text.ngrams(n=2) # default is 3
# Out:
# [WordList(['now', 'is']),
#  WordList(['is', 'better']),
#  WordList(['better', 'than']),
#  WordList(['than', 'tomorrow'])]

# %%
#

# %%
review='''the covid situation is india is getting worse!!
            another implending lockdown'''

# %%
emotions=TextBlob(review)

# %%
emotions.sentiment
# it returns emotion polarity and emotiuon subjectivity
# polarity (-1,1) where -1 is negative emotion and  +1 is positive feedback
# subjectivity (0 to 0.5) means facts  and (0.5 to 1 )-->opinion
# Out:
# Sentiment(polarity=-0.4, subjectivity=0.6)

# %%
review='''the product is fantastic!!'''
emotions=TextBlob(review)
emotions.sentiment
# Out:
# Sentiment(polarity=0.625, subjectivity=0.9)

# %%
review1='This product is of good quality.'
review2='This product is of good quality!.'
review3='The gil looks lovely.'
review4='This product is of very bad quality.'
review5='This product is of very attractive quality. I purchased some days ago!!!'

# %%
# for i in np.arange(1,6):
    
emotions1=TextBlob(review1)
emotions2=TextBlob(review2)
emotions3=TextBlob(review3)
emotions4=TextBlob(review4)
emotions5=TextBlob(review5)

# %%
print(emotions1.sentiment)
print(emotions2.sentiment)
print(emotions3.sentiment)
print(emotions4.sentiment)
print(emotions5.sentiment)
# Out:
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.875, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.5, subjectivity=0.75)
# Sentiment(polarity=-0.9099999999999998, subjectivity=0.8666666666666667)
# Sentiment(polarity=1.0, subjectivity=1.0)

# %% [markdown]
# # Enumerate

# %%
for index,value in enumerate (review_list):
    print(index,value)
# Out:
# 0 This product is of good quality.
# 1 This product is of good quality!.
# 2 The gil looks lovely.
# 3 This product is of very bad quality.
# 4 This product is of very attractive quality. I purchased some days ago!!!

# %%
review_list=[review1,review2,review3,review4,review5]
for index,value in enumerate (review_list):
    emotions=TextBlob(value)
    
    arr=np.array(emotions.sentiment)
    
    plt.scatter(arr[0],arr[1])
    plt.text(arr[0]+0.05,arr[1]+0.05,index)  #+0.05 to adjust size of text
plt.xlabel('polarity')
plt.ylabel('subjectivity')
plt.xlim(-1,1)
plt.ylim=(0,1)

# latex use for mathematical notation
plt.title(r'$\sqrt{25}$')
# plotting in a graph
# Out:
# Text(0.5, 1.0, '$\\sqrt{25}$')

# %%
# enumerate return number and values
