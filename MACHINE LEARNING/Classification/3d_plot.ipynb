# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# fig= plt.figure()
# as = plt.axes(projection='3d')
x=np.arange(-5,5,0.1)
y=np.arange(-5,5,0.1)
print(x.shape,y.shape)
X,Y=np.meshgrid(x,y)
# Z=X+Y
Z=X*np.exp(-X**2-Y**2)
# Out:
# (100,) (100,)

# %%
Z.shape
# 3d
# Out:
# (100, 100)

# %%
fig= plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X,Y,Z,cmap='viridis')
# ax.contourf(X,Y,Z,cmap='viridis')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Z1=log(X)
fig= plt.figure()
ax = plt.axes(projection='3d')
# ax.plot_surface(X,Y,Z,cmap='viridis')
ax.contourf(X,Y,Z1,cmap='viridis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24932/2524202339.py in <module>
# ----> 1 Z1=log(X)
#       2 fig= plt.figure()
#       3 ax = plt.axes(projection='3d')
#       4 # ax.plot_surface(X,Y,Z,cmap='viridis')
#       5 ax.contourf(X,Y,Z1,cmap='viridis')
#
# NameError: name 'log' is not defined

# %%
fig= plt.figure()
ax = plt.axes(projection='3d')
# ax.plot_surface(X,Y,Z,cmap='viridis')
ax.contourf(X,Y,Z,cmap='viridis')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
