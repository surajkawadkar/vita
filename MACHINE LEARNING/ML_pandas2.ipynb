# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# we can read anything like clipboard html csv, sql
# clipboord we need tabular data copy it it will store it some memory and that will read  in clipboard

# %%
# clipboard will not work on colab
clip=pd.read_clipboard()
print(clip)
# Out:
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# <ipython-input-3-1f301484f844> in <module>()
# ----> 1 clip=pd.read_clipboard()
#       2 print(clip)
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      36     from pandas.io.parsers import read_csv
#      37
# ---> 38     text = clipboard_get()
#      39
#      40     # Try to decode (if needed, as "text" might already be a string here).
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/clipboard/__init__.py in lazy_load_stub_paste()
#     647     global copy, paste
#     648     copy, paste = determine_clipboard()
# --> 649     return paste()
#     650
#     651
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/clipboard/__init__.py in __call__(self, *args, **kwargs)
#     285     class ClipboardUnavailable:
#     286         def __call__(self, *args, **kwargs):
# ...

# %%
# downlOAD FILE IN EXCEL FORMAT
df1.to_excel('saample.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-31c5300a85a5> in <module>()
#       1 # downlOAD FILE IN EXCEL FORMAT
# ----> 2 df1.to_excel('saample.xlsx')
#
# NameError: name 'df1' is not defined

# %%
# Read html data from api
df2=pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')
df2
# Out:
# [                         Bank NameBank  ... FundFund
#  0                    Almena State Bank  ...    10538
#  1           First City Bank of Florida  ...    10537
#  2                 The First State Bank  ...    10536
#  3                   Ericson State Bank  ...    10535
#  4     City National Bank of New Jersey  ...    10534
#  ..                                 ...  ...      ...
#  558                 Superior Bank, FSB  ...     6004
#  559                Malta National Bank  ...     4648
#  560    First Alliance Bank & Trust Co.  ...     4647
#  561  National State Bank of Metropolis  ...     4646
#  562                   Bank of Honolulu  ...     4645
#
#  [563 rows x 7 columns]]

# %%
# importing whole page it is in list not a dataframe
type(df2)
# Out:
# list

# %%
# lets access qst element of list
# this is dataframe 
df2[0]
# Out:
#                          Bank NameBank  ... FundFund
# 0                    Almena State Bank  ...    10538
# 1           First City Bank of Florida  ...    10537
# 2                 The First State Bank  ...    10536
# 3                   Ericson State Bank  ...    10535
# 4     City National Bank of New Jersey  ...    10534
# ..                                 ...  ...      ...
# 558                 Superior Bank, FSB  ...     6004
# 559                Malta National Bank  ...     4648
# 560    First Alliance Bank & Trust Co.  ...     4647
# 561  National State Bank of Metropolis  ...     4646
# 562                   Bank of Honolulu  ...     4645
#
# [563 rows x 7 columns]

# %%
type(df2[0])
# Out:
# pandas.core.frame.DataFrame

# %%
# to save this dataframe info or table in our local drive
# check staorage file in colab or download folder in jupyter
df2[0].to_excel('failed-bank.xlsx')

# %%
# when you iterate a list will get dataframe cause all tables are stores in list

# %%
# For Api Calls
import requests
response = requests.get("https://pokeapi.co/api/v2/pokemon/1")

print(response.status_code) # 200 for successfully get the response and 404 for page not found
# documentation says that we get an response in json format
print(response.json())
# Out:
# 200
# ...

# %%
# to make it readaable
import json

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(response.json())
# Out:
# {
#     "abilities": [
#         {
#             "ability": {
#                 "name": "overgrow",
#                 "url": "https://pokeapi.co/api/v2/ability/65/"
#             },
#             "is_hidden": false,
#             "slot": 1
#         },
#         {
#             "ability": {
#                 "name": "chlorophyll",
#                 "url": "https://pokeapi.co/api/v2/ability/34/"
#             },
#             "is_hidden": true,
#             "slot": 3
#         }
#     ],
#     "base_experience": 64,
#     "forms": [
#         {
#             "name": "bulbasaur",
#             "url": "https://pokeapi.co/api/v2/pokemon-form/1/"
#         }
#     ],
#     "game_indices": [
#         {
#             "game_index": 153,
#             "version": {
#                 "name": "red",
#                 "url": "https://pokeapi.co/api/v2/version/1/"
#             }
#         },
#         {
#             "game_index": 153,
#             "version": {
# ...

# %%
# multiple dataframs are there inside list
df4=pd.read_html('https://en.wikipedia.org/wiki/List_of_highest-grossing_films')
df4[2]
# Out:
#      Year  ...        Reference(s)
# 0    1915  ...  [# 82][# 83][# 84]
# 1    1916  ...        [# 85][# 86]
# 2    1917  ...              [# 85]
# 3    1918  ...              [# 87]
# 4    1919  ...              [# 88]
# ..    ...  ...                 ...
# 142  2017  ...              [# 25]
# 143  2018  ...        [# 9][# 297]
# 144  2019  ...               [# 3]
# 145  2020  ...      [# 298][# 299]
# 146  2021  ...      [# 300][# 301]
#
# [147 rows x 5 columns]

# %%
# to rad from dict
d={'a':[1,2,3],
 'b':['a','b','c']}
pd.DataFrame(d)
# Out:
#    a  b
# 0  1  a
# 1  2  b
# 2  3  c

# %%
d={'a':[1,2,3],
 'b':['a','b',np.nan]}
q=pd.DataFrame(d)

# %%
q.to_json('test.json')
# check in collab  files

# %%
# Groupping
# Grouping
# Groupping
# Grouping
# Groupping
# Grouping
# Groupping
# Grouping
# Groupping
# Grouping

# %%
data = {'Company':['RIL','RIL','TCS','TCS','ICICI','ICICI'],
       'Person':['Anushka','Ramdeo','Archana','Vineeta','Ritika','Sapna'],
       'Sales':[200,120,340,124,243,350]}
co_df=pd.DataFrame(data)

# %%
co_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  6 non-null      object
#  1   Person   6 non-null      object
#  2   Sales    6 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 272.0+ bytes

# %%
co_df
# Out:
#   Company   Person  Sales
# 0     RIL  Anushka    200
# 1     RIL   Ramdeo    120
# 2     TCS  Archana    340
# 3     TCS  Vineeta    124
# 4   ICICI   Ritika    243
# 5   ICICI    Sapna    350

# %%
by_comp=co_df.groupby('Company')

# %%
type(by_comp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# ICICI     2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# RIL       2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# TCS       2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.sum()
# sum group by company name
# Out:
#          Sales
# Company
# ICICI      593
# RIL        320
# TCS        464

# %%
# to change column name 
new_cols=['a','b','c']
co_df.columns=new_cols
co_df
# Out:
#        a        b    c
# 0    RIL  Anushka  200
# 1    RIL   Ramdeo  120
# 2    TCS  Archana  340
# 3    TCS  Vineeta  124
# 4  ICICI   Ritika  243
# 5  ICICI    Sapna  350

# %%
# change one column name only
co_df.rename(columns={'c':'sales'})
co_df
# Out:
#        a        b    c
# 0    RIL  Anushka  200
# 1    RIL   Ramdeo  120
# 2    TCS  Archana  340
# 3    TCS  Vineeta  124
# 4  ICICI   Ritika  243
# 5  ICICI    Sapna  350

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a9d95262-a2d5-44e7-8f58-7f906597ed15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9d95262-a2d5-44e7-8f58-7f906597ed15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving jamesbond.csv to jamesbond.csv

# %%
import pandas as pd
import io
bonds= pd.read_csv(io.BytesIO(uploaded['jamesbond.csv']))
print(bonds)
# Out:
#                                Film  Year  ... Budget Bond Actor Salary
# 0                            Dr. No  1962  ...    7.0               0.6
# 1             From Russia with Love  1963  ...   12.6               1.6
# 2                        Goldfinger  1964  ...   18.6               3.2
# 3                       Thunderball  1965  ...   41.9               4.7
# 4                     Casino Royale  1967  ...   85.0               NaN
# 5               You Only Live Twice  1967  ...   59.9               4.4
# 6   On Her Majesty's Secret Service  1969  ...   37.3               0.6
# 7              Diamonds Are Forever  1971  ...   34.7               5.8
# 8                  Live and Let Die  1973  ...   30.8               NaN
# 9       The Man with the Golden Gun  1974  ...   27.7               NaN
# 10             The Spy Who Loved Me  1977  ...   45.1               NaN
# 11                        Moonraker  1979  ...   91.5               NaN
# ...

# %%
# groupping by actor with all clumn 
# here problem is year cannot be add so go with specifir column
by_actor=bonds.groupby('Actor')
by_actor.sum()
# Out:
#                  Year  Box Office  Budget  Bond Actor Salary
# Actor
# Daniel Craig     8041      2765.9   703.2               25.9
# David Niven      1967       315.0    85.0                0.0
# George Lazenby   1969       291.5    37.3                0.6
# Pierce Brosnan   7993      1886.6   523.3               46.5
# Roger Moore     13852      2960.7   363.7               16.9
# Sean Connery    13775      3997.8   260.7               20.3
# Timothy Dalton   3976       564.4   125.5               13.1

# %%
# groupby for specific column only
by_actor['Box Office','Budget','Bond Actor Salary'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 Box Office  Budget  Bond Actor Salary
# Actor
# Daniel Craig        2765.9   703.2               25.9
# David Niven          315.0    85.0                0.0
# George Lazenby       291.5    37.3                0.6
# Pierce Brosnan      1886.6   523.3               46.5
# Roger Moore         2960.7   363.7               16.9
# Sean Connery        3997.8   260.7               20.3
# Timothy Dalton       564.4   125.5               13.1

# %%
# box office collection by all actors
bonds[['Box Office','Actor']].boxplot(by='Actor',figsize=(14,5))

plt.savefig('collection data pic.png')  #save image in local storage
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# box office and budget collection by all actors
bonds[['Box Office','Budget','Actor']].boxplot(by='Actor',figsize=(14,5))
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe720b20550>,
# ...
#       dtype=object)

# %%
#Handling Missing data
#Handling Missing data# Missing data
# Handling Missing data
# Handling Missing data# Missing data
# Missing data
# Missing data
# Missing data

# %%
df = pd.DataFrame({'A':[10,20,np.nan,40],
                  'B':[5,np.nan,np.nan,np.nan],
                  'C':[1,2,3,4]})

# %%
df
# Out:
#       A    B  C
# 0  10.0  5.0  1
# 1  20.0  NaN  2
# 2   NaN  NaN  3
# 3  40.0  NaN  4

# %%
# complete na daata drop  temporarily 
# dropna()  drop all where atleast one na
df.dropna()
# Out:
#       A    B  C
# 0  10.0  5.0  1

# %%
df
# Out:
#            A    B  C
# 0  10.000000  5.0  1
# 1  20.000000  5.0  2
# 2  23.333333  5.0  3
# 3  40.000000  5.0  4

# %%
df.isna()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False
# 3  False   True  False

# %%
# drop columns where value is na
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3
# 3  4

# %%
# allow na values mentioned
df.dropna(axis=1,thresh=2)
# Out:
#       A  C
# 0  10.0  1
# 1  20.0  2
# 2   NaN  3
# 3  40.0  4

# %%
# fill with aarbirtary text where na is there
df.fillna('Not Available')
# Out:
#                A              B  C
# 0             10              5  1
# 1             20  Not Available  2
# 2  Not Available  Not Available  3
# 3             40  Not Available  4

# %%
df['A'].fillna(df['A'].mean())
# fill by mean
# avg by how many row by numbers are there
# though total row are 4 but total numbers is row are present is 3
# Out:
# 0    10.000000
# 1    20.000000
# 2    23.333333
# 3    40.000000
# Name: A, dtype: float64

# %%
df.fillna(df.mean())
# fill with mean value all over na value
# Out:
#            A    B  C    D
# 0  10.000000  5.0  1  120
# 1  20.000000  5.0  2  120
# 2  23.333333  5.0  3  120
# 3  40.000000  5.0  4  120

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'D'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.fillna(df.mean(),inplace=True)
df
# fill all column in one go
# Out:
#            A    B  C
# 0  10.000000  5.0  1
# 1  20.000000  5.0  2
# 2  23.333333  5.0  3
# 3  40.000000  5.0  4

# %%
df['D']=120

# add column

# %%
df
# Out:
#       A    B  C    D
# 0  10.0  5.0  1  120
# 1  20.0  NaN  2  120
# 2   NaN  NaN  3  120
# 3  40.0  NaN  4  120

# %%
df['E']=df.apply(lambda r: 'good' if r.A>20 else 'bad', axis=1)
df
# Out:
#       A    B  C    D     E
# 0  10.0  5.0  1  120   bad
# 1  20.0  NaN  2  120   bad
# 2   NaN  NaN  3  120   bad
# 3  40.0  NaN  4  120  good

# %%
# use jamesbonds data again

Remarks
# Out:
#       A    B  C    D
# 0  10.0  5.0  1  120
# 1  20.0  NaN  2  120
# 2   NaN  NaN  3  120
# 3  40.0  NaN  4  120

# %%
# add remark if actor daanie best if david worsr else no clue
def remark_func(row):
  
  if row.Actor=='Daniel Craig':
    return 'best movie'
  elif row.Actor=='David Niven':
    return 'worst movie'
  else:
    return 'no clue'

bonds['Remarks']=bonds.apply(remark_func, axis=1)
bonds
# Out:
#                                Film  Year  ... Bond Actor Salary      Remarks
# 0                            Dr. No  1962  ...               0.6      no clue
# 1             From Russia with Love  1963  ...               1.6      no clue
# 2                        Goldfinger  1964  ...               3.2      no clue
# 3                       Thunderball  1965  ...               4.7      no clue
# 4                     Casino Royale  1967  ...               NaN  worst movie
# 5               You Only Live Twice  1967  ...               4.4      no clue
# 6   On Her Majesty's Secret Service  1969  ...               0.6      no clue
# 7              Diamonds Are Forever  1971  ...               5.8      no clue
# 8                  Live and Let Die  1973  ...               NaN      no clue
# 9       The Man with the Golden Gun  1974  ...               NaN      no clue
# 10             The Spy Who Loved Me  1977  ...               NaN      no clue
# ...

# %%
bonds
# Out:
#                                Film  Year  ... Budget Bond Actor Salary
# 0                            Dr. No  1962  ...    7.0               0.6
# 1             From Russia with Love  1963  ...   12.6               1.6
# 2                        Goldfinger  1964  ...   18.6               3.2
# 3                       Thunderball  1965  ...   41.9               4.7
# 4                     Casino Royale  1967  ...   85.0               NaN
# 5               You Only Live Twice  1967  ...   59.9               4.4
# 6   On Her Majesty's Secret Service  1969  ...   37.3               0.6
# 7              Diamonds Are Forever  1971  ...   34.7               5.8
# 8                  Live and Let Die  1973  ...   30.8               NaN
# 9       The Man with the Golden Gun  1974  ...   27.7               NaN
# 10             The Spy Who Loved Me  1977  ...   45.1               NaN
# 11                        Moonraker  1979  ...   91.5               NaN
# ...
